# %% [markdown]
# <a href="https://colab.research.google.com/github/SehanArandara/DL-Codepro/blob/main/04_CNN_with_Stride%2Cpadding%2Cpooling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN  - Convolutional Neural Network
#
# - we use this DL models for image processing and videos
# - So that we have to add some new layers to the before the simple nueral netowork because we have to get the features from the image and after that we have to put it into the NN

# %% [markdown]
# ## Convolutional Layers
#
# -  this is the main componet of the CNN
# - ![cnn.png](data:image/png;base64,...)
#
#
# - so in here we can see the basic structure of a CNN

# %% [markdown]
# ### How to calculate the size of the matrix with onyl with filter
#
# - we use filter to detect the fatures from the image in convolutional layer
#
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Padding in CNN
#
# - we use padding to give equal priority to the all the pixel
# - from that all the pixels will contribute with the all the process
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - There are two types of paddings
# - they are
# 1. Valid Padding
# 2. Same Padding
#
# - in same padding we can calculate the value for the padding like this
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Stride for CNN
#
# - Define how many pixel we want to move the filter or kernel
# - we can calculate the output like the below
# - if there is values like 2.7 . 2.8 we have to get the floor values of that . That is means the value is 2
# - ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Pooling layers
#
# - these are use to enhance the fatures of the images
# - we can use the pooling layers to Reduce the computational cost by reducing the image size
# - There are two main two types of pooling layers
# - They are max pooling and average pooling
# - ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Simple example for the CNN with pooling layers
#
# ![image.png](data:image/png;base64,...)

# %%
import tensorflow as tf

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(10,(5,5),activation='relu',input_shape=(64,64,3)),
    tf.keras.layers.MaxPooling2D((3,3),strides=(3,3)),

    tf.keras.layers.Conv2D(16,(5,5),activation='relu',input_shape=(64,64,3)),
    tf.keras.layers.MaxPooling2D((2,2),strides=(2,2)),

    tf.keras.layers.Flatten() ,

    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(16,activation='relu'),

    tf.keras.layers.Dense(1,activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 60, 60, 10)          │             760 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 20, 20, 10)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 16, 16, 16)          │           4,016 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 16)            │               0 │
# ...
