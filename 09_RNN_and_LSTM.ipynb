# %% [markdown]
# <a href="https://colab.research.google.com/github/SehanArandara/DL-Codepro/blob/main/09_RNN_and_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Recurrent Nueral Netoworks
#
# - we use these kind of model to process the seqeuntial data
# - Sequential data means they have an order like audio ,  text and etc
# - So we can use this for Sequential Data and the architecture will be like the below
# - ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Types of RNN
#
# 1. One to one - one input one output
# 2. One to many - one input and more output
# 3. Many to one - Many input and one output
# 4. Many to many - Many input and many output

# %% [markdown]
# ## Limitations of the RNN
#
# - problem in storing long term dependecies
# - Vanishing gradient problem

# %% [markdown]
# ## LSTM
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - There are three gates in LSTM
#
# 1. Forget Gate
# 2. Input gate
# 3. Output gate
#
# ### Forget gate
# - what are things we need to forget in long term memory
#
# ### Input Gate
# - closest things we input the nuerons
#
# ### Output Gate
# - Given predictions
